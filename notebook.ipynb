# %%
import os
import cv2
import numpy as np

# %%
image_path = 'images/men_shirt_model_mask.png'
image = cv2.imread(image_path)

# %%
from matplotlib import pyplot as plt
plt.imshow(image)
plt.show()

# %%
image[1200,600,:]
# Out:
# array([  0,   0, 128], dtype=uint8)

# %%
image[1400,600,:]
# Out:
# array([  0, 128,   0], dtype=uint8)

# %%
target_color = np.array([0, 0, 128]) # Replace B, G, R with the actual values

# Define a tolerance for color matching
tolerance = 0

# Create lower and upper bounds for the target color
lower_bound = np.clip(target_color - tolerance, 0, 255)
upper_bound = np.clip(target_color + tolerance, 0, 255)

# Create a mask that identifies the target color
mask = cv2.inRange(image, lower_bound, upper_bound)

# Create an output image where only the target color remains
output_image = np.zeros_like(image)

# mask = np.all(image != target_color, axis=-1)
# output_image = np.zeros_like(image)


# image[upper_body] = [0, 0, 0]
plt.imshow(mask)
plt.show()

# %%
lower_body = np.all(image[:, :, :3] == [0, 128, 0], axis=-1)
